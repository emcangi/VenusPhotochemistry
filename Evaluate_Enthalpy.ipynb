# %%
using Revise
using DataFrames
using XLSX
photochemistry_source_dir = "$(@__DIR__)/Photochemistry/src/"
push!(LOAD_PATH, photochemistry_source_dir)
using Photochemistry  # custom module
# Out:
# ┌ Info: Precompiling Photochemistry [top-level]
# └ @ Base loading.jl:1423

# %%
include("CONSTANTS.jl");

# %%
function escape_velocity()
    #=
    Returns escape velocity for the present planet defined in CONSTANTS.jl in m/s.
    =#
    return sqrt(2 * bigG * M_P / R_P) / 100 # the / 100 is to convert from cm to m.
end

escape_velocity()
# Out:
# 10359.311697355919

# %%
kJ_to_eV(kj) = kj * 6.242e21

function escape_energy(z)
    #=
    Calculates escape energy from planet P for a molecule containing z protons.
    =#
    
    kJ_to_eV((0.5 * z * (1.67e-27 #=kg=#) * (escape_velocity() #=m/s=#)^2) / 1000 #=kJ/J=#)
end

ev_per_molecule(eV_per_mole) = eV_per_mole/6.022e23

function enthalpy_of_reaction(reactants, products, enthalpy_dict)
    
    dfH_products = 0
    dfH_reactants = 0

    for p in products
        dfH_products += enthalpy_dict[p]
    end
    for r in reactants
        dfH_reactants += enthalpy_dict[r]
    end

    # Calculate the total enthalpy of reaction:
    enthalpy_of_rxn = dfH_products - dfH_reactants
    
    # this block adds up the total mass that needs to escape, allows for reactions that produce, e.g., both H and D
    m = 0 
    flag = 0
    if :H in products
        m += 1
        flag += 1
    end
    if :H2 in products
        m += 2
        flag += 1
    end
    if :D in products
        m += 2
        flag += 1
    end
    if :HD in products
        m += 3
        flag += 1
    end
        
    # Convert the total enthalpy of reaction to eV:
    total_reaction_enthalpy_ev = ev_per_molecule(kJ_to_eV(-1*(enthalpy_of_rxn)))
    
    # Calculate how much energy goes into escaping the hot atoms:
    energy_required_to_escape_all_hot = escape_energy(m)
    
    # Calculate how much excess energy we have
    excess_energy = round(total_reaction_enthalpy_ev - energy_required_to_escape_all_hot, digits=2)

    # Calculate whether endothermic or exothermic
    endo_exo = excess_energy > 0 ? "exothermic" : "endothermic"
    
    println("Reaction $(format_chemistry_string(reactants, products))")
    if flag > 1
        println("Flag! Reaction produces two hot atoms")
    end
    println("Raw enthalpy is $(total_reaction_enthalpy_ev) eV")
    println("Mass to escape $(m), so need a minimum of $(m*escape_energy(1)) eV")
    println("excess energy $(excess_energy).")
    println("Positive excess energy: $(excess_energy > 0), so reaction is $(endo_exo)")
    println()
    
    return endo_exo, total_reaction_enthalpy_ev, energy_required_to_escape_all_hot, excess_energy
end

function get_product_and_reactant_cols(df)
    # Determine how many reactant and product columns there are 
    possible_Rcols = ["R1", "R2", "R3"]
    possible_Pcols = ["P1", "P2", "P3"]
    rcols = Symbol.(possible_Rcols[possible_Rcols .∈ Ref(names(df))])
    pcols = Symbol.(possible_Pcols[possible_Pcols .∈ Ref(names(df))])
    
    return rcols, pcols
end

function calculate_enthalpies(df; species=[:H, :D, :H2, :HD], new_cols=nothing, insert_i=nothing)
    #=
    df: A dataframe containing the contents of a reaction spreadsheet to which we must add excess energies
    
    insert_i here should be the first integer at which we will begin inserting columns.
    =#
    
    #Enthalpy of formation 
    enthalpy_df = DataFrame(XLSX.readtable("./Resources/Enthalpies_of_Formation.xlsx", "enthalpy"))
    
    enthalpy = Dict([Symbol(k)=>df_lookup(enthalpy_df, "Species", k, "Enthalpy")[1] for k in enthalpy_df."Species"])

    
    if new_cols != nothing
        j = 0
        for name in new_cols
            insertcols!(df, insert_i+j, "$(name)"=>["" for x in collect(1:size(df)[1])])
            j += 1
        end
    end
    
    rcols, pcols = get_product_and_reactant_cols(df)
    
    # Count endothermic and exothermic
    endo_count = 0
    exo_count = 0
    
    for row in eachrow(df)
        reactants = [Symbol(row.:($r)) for r in rcols]
        products = filter!(x->x!=:none, [Symbol(row.:($p)) for p in pcols])
        
        # Ignore reactions for which we don't have enthalpies of a species:
        if any(x->!(x in keys(enthalpy)), union(reactants, products))
            continue
        end

        if any(x->x in products, species)
            exo_or_endo, total_enthalpy, loss_energy, excess_energy = enthalpy_of_reaction(reactants, products, enthalpy)
            row.rxnEnthalpy = total_enthalpy
            row.totalEscE = loss_energy
            row.excessE = excess_energy
            
            if exo_or_endo == "exothermic"
                exo_count += 1
                row.NTEscape = "Yes"

                if :D in products
                    row.hotD = "Yes"
                end
                if :HD in products
                    row.hotHD = "Yes"
                end
                
                if :H in products
                    row.hotH = "Yes"
                end
                if :H2 in products
                    row.hotH2 = "Yes"
                end
            else 
                # println("$(format_chemistry_string(reactants, products)) is endothermic")
                # println()
                endo_count += 1
                row.NTEscape = "No"
                if :D in products
                    row.hotD = ""
                end
                if :HD in products
                    row.hotHD = ""
                end
                
                if :H in products
                    row.hotH = ""
                end
                if :H2 in products
                    row.hotH2 = ""
                end
            end
        end
    end
    
    println("Exothermic: $(exo_count), Endothermic: $(endo_count)")
    return df
end

function modify_rxn_spreadsheet(spreadsheet; spc=nothing, new_cols=nothing, insert_i=nothing)
    #=
    insert_i is a list of integers at which to insert columns. The order in this list corresponds to the order of sheets in the workbook.
    =#
    xf = XLSX.readxlsx(spreadsheet)
    original_sheets = XLSX.sheetnames(xf)
    
    new_file = "REACTION_NETWORK_VENUS.xlsx"   # "MOLEC_NT_$(spreadsheet)"#
    
    @assert spc != nothing
    
    # Go through each available sheet and open it as a dataframe for modification
    for (j, sheet) in enumerate(original_sheets)
        df = DataFrame(XLSX.readtable(spreadsheet, sheet));
               
        # Now process:        
        if sheet in ["Ion reactions", "Photodissociation", "Photoionization"]
            # Replace any missing values so we don't get rid of all our reactions before processing:
            rcols, pcols = get_product_and_reactant_cols(df)
            for r in rcols
                replace!(df.:($r), missing=>"none")
            end
            for p in pcols
                replace!(df.:($p), missing=>"none")
            end
            
            if insert_i != nothing
                df_to_write = calculate_enthalpies(df; species=spc, new_cols=new_cols, insert_i=insert_i[j])
            else 
                df_to_write = calculate_enthalpies(df; species=spc)
            end
        else
            df_to_write = df
        end
        println()
        log_reactions(df_to_write, sheet, new_file)
    end
end
# Out:
# modify_rxn_spreadsheet (generic function with 1 method)

# %%
# NOT USED but left here to easily see
# esc_in_ev_per_species = Dict(:H=>escape_energy(1), :D=>escape_energy(2), :H2=>escape_energy(2), :HD=>escape_energy(3))
# Out:
# Dict{Symbol, Float64} with 4 entries:
#   :H  => 0.559335
#   :D  => 1.11867
#   :H2 => 1.11867
#   :HD => 1.67801

# %%
modify_rxn_spreadsheet("REACTION_NETWORK_VENUS_start.xlsx"; spc=[:H2, :HD, :H, :D])#, new_cols=["rxnEnthalpy", "totalEscE"], insert_i=[0,7,8,8,0,0])
# Out:
# Reaction ArDpl + H2 --> ArHpl + HD
# Raw enthalpy is 0.11795742278312965 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy -1.56.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Arpl + H2 --> ArHpl + H
# Raw enthalpy is -12.591799402191961 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -13.15.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Arpl + HD --> ArDpl + H
# Raw enthalpy is -12.70975682497509 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -13.27.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Arpl + HD --> ArHpl + D
# Raw enthalpy is -12.647772168714711 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -13.77.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction CHpl + H --> Cpl + H2
# Raw enthalpy is 0.38869976751909663 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -0.73.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction CHpl + H2O --> HCOpl + H2
# Raw enthalpy is 5.748610428429091 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 4.63.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction CHpl + O --> COpl + H
# Raw enthalpy is 4.266368648289603 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 3.71.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction CHpl + OH --> COpl + H2
# Raw enthalpy is 4.345145134506809 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 3.23.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction CO2pl + H2 --> HCO2pl + H
# Raw enthalpy is 1.3547482563932252 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.8.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction CO2pl + HD --> DCO2pl + H
# Raw enthalpy is 1.2969097309863844 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.74.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction CO2pl + HD --> HCO2pl + D
# Raw enthalpy is 1.2987754898704755 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.18.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction COpl + H2 --> HCOpl + H
# Raw enthalpy is 2.0388598472268353 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.48.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction COpl + H2 --> HOCpl + H
# Raw enthalpy is 0.6146638990368644 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.06.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction COpl + HD --> DCOpl + H
# Raw enthalpy is 1.9561445366987689 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.4.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction COpl + HD --> DOCpl + H
# Raw enthalpy is 0.5184736632348054 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -0.04.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction COpl + HD --> HCOpl + D
# Raw enthalpy is 1.9828870807040844 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.86.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction COpl + HD --> HOCpl + D
# Raw enthalpy is 0.5586911325141134 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -0.56.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Cpl + H2 --> CHpl + H
# Raw enthalpy is -0.38869976751909663 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -0.95.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Cpl + H2O --> HCOpl + H
# Raw enthalpy is 5.359910660909995 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 4.8.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Cpl + H2O --> HOCpl + H
# Raw enthalpy is 3.9357147127200243 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 3.38.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Cpl + HD --> CHpl + D
# Raw enthalpy is -0.4446725340418475 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -1.56.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Cpl + HDO --> DCOpl + H
# Raw enthalpy is 5.207747658585186 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 4.65.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Cpl + HDO --> DOCpl + H
# Raw enthalpy is 3.7700767851212222 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 3.21.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Cpl + HDO --> HCOpl + D
# Raw enthalpy is 5.234490202590501 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 4.12.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Cpl + HDO --> HOCpl + D
# Raw enthalpy is 3.81029425440053 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 2.69.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Cpl + OH --> COpl + H
# Raw enthalpy is 3.9564453669877118 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 3.4.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction DCOpl + H --> HCOpl + D
# Raw enthalpy is 0.02674254400531545 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -1.09.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction DOCpl + H2 --> HCOpl + HD
# Raw enthalpy is 1.5203861839920285 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy -0.16.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Dpl + CO2 --> CO2pl + D
# Raw enthalpy is -0.1057263367651971 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -1.22.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Dpl + H --> D + Hpl
# Raw enthalpy is 0.06841115908336005 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -1.05.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Dpl + H2 --> Hpl + HD
# Raw enthalpy is 0.1243839256061109 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy -1.55.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Dpl + H2O --> HDOpl + H
# Raw enthalpy is 1.0128997675190945 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.45.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Dpl + H2O --> H2Opl + D
# Raw enthalpy is 1.0551903022251736 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -0.06.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Dpl + NO --> NOpl + D
# Raw enthalpy is 4.399044835602788 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 3.28.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Dpl + O --> D + Opl
# Raw enthalpy is 0.04871703752905822 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -1.07.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Dpl + O2 --> O2pl + D
# Raw enthalpy is 1.5952238458983712 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.48.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2Dpl + CO --> HCOpl + HD
# Raw enthalpy is 1.8489670541348375 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy 0.17.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2Dpl + CO --> DCOpl + H2
# Raw enthalpy is 1.7662517436067748 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.65.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2Dpl + H2 --> H3pl + HD
# Raw enthalpy is 0.11173822650282268 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy -1.57.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H2Opl + H2 --> H3Opl + H
# Raw enthalpy is 1.7092424443706407 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.15.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2Opl + HD --> H2DOpl + H
# Raw enthalpy is -3.7043606110926586 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -4.26.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H2Opl + HD --> H3Opl + D
# Raw enthalpy is 1.6532696778478908 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.53.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2Opl + N --> NOpl + H2
# Raw enthalpy is 4.816767519096645 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 3.7.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2Opl + N --> HNOpl + H
# Raw enthalpy is 1.6408312852872793 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.08.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2Opl + O --> O2pl + H2
# Raw enthalpy is 0.6219196280305546 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -0.5.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H2pl + Ar --> ArHpl + H
# Raw enthalpy is 1.110126536034539 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.55.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + C --> CHpl + H
# Raw enthalpy is 3.7771252075722357 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 3.22.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + CO --> COpl + H2
# Raw enthalpy is 1.4117575556293593 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.29.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + CO --> HCOpl + H
# Raw enthalpy is 3.4506174028561944 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 2.89.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + CO2 --> HCO2pl + H
# Raw enthalpy is 3.008017934241114 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 2.45.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + H --> Hpl + H2
# Raw enthalpy is 1.8274071736964457 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.71.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + H2 --> H3pl + H
# Raw enthalpy is 1.7133885752241773 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.15.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + H2O --> H2Opl + H2
# Raw enthalpy is 2.814186316838258 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 1.7.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + H2O --> H3Opl + H
# Raw enthalpy is 4.523428761208899 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 3.96.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + HCO --> HCOpl + H2
# Raw enthalpy is 7.333468947193621 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 6.21.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + N --> NHpl + H
# Raw enthalpy is 3.9813221521089326 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 3.42.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + N2 --> N2Hpl + H
# Raw enthalpy is 2.4545094652939214 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.9.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + NO --> NOpl + H2
# Raw enthalpy is 6.158040850215873 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 5.04.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + NO --> HNOpl + H
# Raw enthalpy is 2.982104616406507 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 2.42.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + O --> OHpl + H
# Raw enthalpy is 2.346710063101958 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.79.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + O2 --> O2pl + H2
# Raw enthalpy is 3.3542198605114564 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 2.24.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + O2 --> HO2pl + H
# Raw enthalpy is 1.6978405845234135 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.14.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + OH --> OHpl + H2
# Raw enthalpy is 2.425486549319163 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 1.31.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + OH --> H2Opl + H
# Raw enthalpy is 3.449580870142809 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 2.89.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H3Opl + C --> HCOpl + H2
# Raw enthalpy is 5.002306874792427 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 3.88.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H3pl + Ar --> ArHpl + H2
# Raw enthalpy is -0.6032620391896384 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -1.72.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H3pl + C --> CHpl + H2
# Raw enthalpy is 2.0637366323480584 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.95.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H3pl + CO --> HCOpl + H2
# Raw enthalpy is 1.737228827632016 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.62.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H3pl + CO --> HOCpl + H2
# Raw enthalpy is 0.3130328794420463 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -0.81.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H3pl + CO2 --> HCO2pl + H2
# Raw enthalpy is 1.2946293590169373 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.18.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H3pl + H2O --> H3Opl + H2
# Raw enthalpy is 2.810040185984722 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 1.69.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H3pl + N --> NHpl + H2
# Raw enthalpy is 2.267933576884755 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 1.15.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H3pl + N2 --> N2Hpl + H2
# Raw enthalpy is 0.7411208900697441 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -0.38.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H3pl + NO --> HNOpl + H2
# Raw enthalpy is 1.26871604118233 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.15.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H3pl + O --> OHpl + H2
# Raw enthalpy is 0.6333214878777804 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -0.49.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H3pl + O --> H2Opl + H
# Raw enthalpy is 1.6574158087014266 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.1.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H3pl + O2 --> HO2pl + H2
# Raw enthalpy is -0.015547990700763863 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -1.13.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H3pl + OH --> H2Opl + H2
# Raw enthalpy is 1.7361922949186326 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.62.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HCOpl + D --> DCOpl + H
# Raw enthalpy is -0.02674254400531545 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -0.59.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HCOpl + OH --> HCO2pl + H
# Raw enthalpy is 0.611554300896712 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.05.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDOpl + H2 --> H2DOpl + H
# Raw enthalpy is -3.6060973098638307 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -4.17.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HDOpl + H2 --> H3Opl + D
# Raw enthalpy is 1.7515329790767187 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.63.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDOpl + N --> NOpl + HD
# Raw enthalpy is 4.915030820325472 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy 3.24.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDOpl + N --> HNOpl + D
# Raw enthalpy is 1.6831218199933562 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.56.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDOpl + O --> O2pl + HD
# Raw enthalpy is 0.7201829292593824 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy -0.96.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HDpl + Ar --> ArDpl + H
# Raw enthalpy is 1.0768849319163047 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.52.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDpl + Ar --> ArHpl + D
# Raw enthalpy is 1.1388695881766835 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.02.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDpl + CO --> DCOpl + H
# Raw enthalpy is 3.4526179109930237 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 2.89.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDpl + CO --> HCOpl + D
# Raw enthalpy is 3.4793604549983392 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 2.36.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDpl + CO2 --> DCO2pl + H
# Raw enthalpy is 3.034895227499167 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 2.48.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDpl + CO2 --> HCO2pl + D
# Raw enthalpy is 3.0367609863832583 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 1.92.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDpl + HD --> H2Dpl + D
# Raw enthalpy is 1.6303934008634993 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.51.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDpl + N2 --> N2Dpl + H
# Raw enthalpy is 2.4347427864496822 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.88.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDpl + N2 --> N2Hpl + D
# Raw enthalpy is 2.4832525174360662 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 1.36.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDpl + O --> ODpl + H
# Raw enthalpy is 2.3010300664231145 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.74.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDpl + O --> OHpl + D
# Raw enthalpy is 2.375453115244102 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 1.26.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDpl + O2 --> HO2pl + D
# Raw enthalpy is 1.726583636665558 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.61.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HOCpl + H2 --> HCOpl + H2
# Raw enthalpy is 1.4241959481899698 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.31.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Hpl + H --> H + Hpl
# Raw enthalpy is 0.0 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -0.56.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Hpl + H2O --> H2Opl + H
# Raw enthalpy is 0.9867791431418113 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.43.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Hpl + HCO --> COpl + H2
# Raw enthalpy is 3.4672019262703415 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 2.35.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Hpl + HCO --> HCOpl + H
# Raw enthalpy is 5.506061773497176 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 4.95.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Hpl + HD --> Dpl + H2
# Raw enthalpy is -0.1243839256061109 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -1.24.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Hpl + HDO --> HDOpl + H
# Raw enthalpy is 0.8190681501162401 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.26.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Hpl + HDO --> H2Opl + D
# Raw enthalpy is 0.8613586848223195 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -0.26.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Hpl + NO --> NOpl + H
# Raw enthalpy is 4.330633676519428 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 3.77.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Hpl + O --> Opl + H
# Raw enthalpy is -0.019694121554301836 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -0.58.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Hpl + O2 --> O2pl + H
# Raw enthalpy is 1.5268126868150111 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.97.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Hpl + OH --> OHpl + H
# Raw enthalpy is 0.5980793756227172 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.04.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction N2Dpl + H --> N2Hpl + D
# Raw enthalpy is 0.04850973098638392 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -1.07.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction N2Hpl + D --> N2Dpl + H
# Raw enthalpy is -0.04850973098638392 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -0.61.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction N2pl + H2 --> N2Hpl + H
# Raw enthalpy is 2.60998937230156 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 2.05.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction N2pl + HD --> N2Dpl + H
# Raw enthalpy is 2.5055068747924256 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.95.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction N2pl + HD --> N2Hpl + D
# Raw enthalpy is 2.554016605778809 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 1.44.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction NHpl + H2O --> HNOpl + H2
# Raw enthalpy is 0.47369545001660385 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -0.64.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction NHpl + N --> N2pl + H
# Raw enthalpy is 1.1453686482896046 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.59.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Npl + H2 --> NHpl + H
# Raw enthalpy is 3.089904018598471 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 2.53.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Npl + HD --> NHpl + D
# Raw enthalpy is 3.0339312520757202 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 1.92.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction ODpl + H2 --> HDOpl + H
# Raw enthalpy is 1.056226834938557 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.5.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction ODpl + H2 --> H2Opl + D
# Raw enthalpy is 1.0985173696446364 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -0.02.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction ODpl + N --> NOpl + D
# Raw enthalpy is 5.91528488874128 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 4.8.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction ODpl + O --> O2pl + D
# Raw enthalpy is 1.7204369976751885 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 0.6.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction OHpl + H2 --> H2Opl + H
# Raw enthalpy is 1.0240943208236462 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.46.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction OHpl + HD --> HDOpl + H
# Raw enthalpy is 0.9258310195948183 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.37.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction OHpl + HD --> H2Opl + D
# Raw enthalpy is 0.9681215543008975 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -0.15.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction OHpl + N --> NOpl + H
# Raw enthalpy is 5.840861839920292 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 5.28.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction OHpl + O --> O2pl + H
# Raw enthalpy is 1.6460139488542007 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.09.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Opl + H2 --> OHpl + H
# Raw enthalpy is 0.5389970109598139 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -0.02.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Opl + HD --> ODpl + H
# Raw enthalpy is 0.4086011956160751 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -0.15.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Opl + HD --> OHpl + D
# Raw enthalpy is 0.4830242444370631 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -0.64.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction Opl + OH --> O2pl + H
# Raw enthalpy is 2.2637874460312197 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.7.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction ArHpl + E --> Ar + H
# Raw enthalpy is 9.838768515443373 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 9.28.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction CHpl + E --> C + H
# Raw enthalpy is 7.171769843905676 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 6.61.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction DCO2pl + E --> CO + O + D
# Raw enthalpy is 2.4895442710063094 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 1.37.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction DCO2pl + E --> CO2 + D
# Raw enthalpy is 7.942742876120889 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 6.82.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction DCOpl + E --> CO + D
# Raw enthalpy is 7.525020192627034 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 6.41.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2DOpl + E --> H2 + O + D
# Flag! Reaction produces two hot atoms
# Raw enthalpy is 6.748657190302223 eV
# Mass to escape 4, so need a minimum of 2.2373402324932226 eV
# excess energy 4.51.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2DOpl + E --> HD + O + H
# Flag! Reaction produces two hot atoms
# Raw enthalpy is 6.804629956824973 eV
# Mass to escape 4, so need a minimum of 2.2373402324932226 eV
# excess energy 4.57.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2DOpl + E --> OH + HD
# Raw enthalpy is 11.203674792427762 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy 9.53.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2DOpl + E --> OD + H2
# Raw enthalpy is 11.219119129857187 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 10.1.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2DOpl + E --> HDO + H
# Raw enthalpy is 11.908517037529057 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 11.35.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2DOpl + E --> OD + H + H
# Raw enthalpy is 6.741297808037195 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 6.18.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2DOpl + E --> H2O + D
# Raw enthalpy is 11.783096579209563 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 10.66.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2DOpl + E --> OH + D + H
# Flag! Reaction produces two hot atoms
# Raw enthalpy is 6.66988070408502 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy 4.99.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2Opl + E --> H2 + O
# Raw enthalpy is 7.578090667552305 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 6.46.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2Opl + E --> O + H + H
# Raw enthalpy is 3.1002693457323147 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 2.54.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2Opl + E --> OH + H
# Raw enthalpy is 7.499314181335103 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 6.94.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H2pl + E --> H + H
# Raw enthalpy is 10.948895051477912 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 10.39.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H3Opl + E --> H2 + O + H
# Flag! Reaction produces two hot atoms
# Raw enthalpy is 1.3910269013616734 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy -0.29.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H3Opl + E --> OH + H2
# Raw enthalpy is 5.790071736964463 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 4.67.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H3Opl + E --> H2O + H
# Raw enthalpy is 6.4254662902690125 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 5.87.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H3Opl + E --> OH + H + H
# Raw enthalpy is 1.3122504151444703 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 0.75.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H3pl + E --> H + H + H
# Raw enthalpy is 4.757685154433742 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 4.2.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction H3pl + E --> H2 + H
# Flag! Reaction produces two hot atoms
# Raw enthalpy is 9.235506476253734 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy 7.56.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HCO2pl + E --> CO + O + H
# Raw enthalpy is 2.4876785121222182 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 1.93.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HCO2pl + E --> CO2 + H
# Raw enthalpy is 7.940877117236798 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 7.38.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HCOpl + E --> CO + H
# Raw enthalpy is 7.498277648621719 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 6.94.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDOpl + E --> HD + O
# Raw enthalpy is 7.676353968781136 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy 6.0.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDOpl + E --> OD + H
# Raw enthalpy is 7.6130218199933575 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 7.05.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDOpl + E --> O + D + H
# Flag! Reaction produces two hot atoms
# Raw enthalpy is 3.1425598804383927 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy 1.46.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDOpl + E --> OH + D
# Raw enthalpy is 7.541604716041181 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 6.42.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HDpl + E --> H + D
# Flag! Reaction produces two hot atoms
# Raw enthalpy is 10.977638103620057 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy 9.3.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HNOpl + E --> NO + H
# Raw enthalpy is 7.966790435071405 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 7.41.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HO2pl + E --> O2 + H
# Raw enthalpy is 9.251054466954498 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 8.69.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction HOCpl + E --> CO + H
# Raw enthalpy is 8.92247359681169 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 8.36.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction Hpl + E --> H
# Raw enthalpy is 13.599309199601459 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 13.04.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction N2Dpl + E --> N2 + D
# Raw enthalpy is 8.542895317170375 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 7.42.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction N2Hpl + E --> N2 + H
# Raw enthalpy is 8.494385586183991 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 7.94.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction NHpl + E --> N + H
# Raw enthalpy is 6.96757289936898 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 6.41.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction ODpl + E --> O + D
# Raw enthalpy is 8.676608037196942 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy 7.56.
# Positive excess energy: true, so reaction is exothermic
#
# Reaction OHpl + E --> O + H
# Raw enthalpy is 8.602184988375955 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy 8.04.
# Positive excess energy: true, so reaction is exothermic
#
# Exothermic: 131, Endothermic: 40
#
# Reaction H2 --> H + H
# Raw enthalpy is -4.4778213218199925 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -5.04.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HD --> H + D
# Flag! Reaction produces two hot atoms
# Raw enthalpy is -4.533794088342743 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy -6.21.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H2O --> H + H + O
# Raw enthalpy is -9.51226071072733 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -10.07.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H2O --> H + OH
# Raw enthalpy is -5.113215875124543 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -5.67.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H2O --> H2 + O1D
# Raw enthalpy is -7.0266552640318825 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -8.15.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H2O2 --> HO2 + H
# Raw enthalpy is -3.725298571903022 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -4.28.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HDO --> D + OH
# Raw enthalpy is -5.238636333444037 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -6.36.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HDO --> H + D + O
# Flag! Reaction produces two hot atoms
# Raw enthalpy is -9.637681169046827 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy -11.32.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HDO --> H + OD
# Raw enthalpy is -5.167219229491862 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -5.73.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HDO --> HD + O1D
# Raw enthalpy is -7.096102955828628 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy -8.77.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HDO2 --> DO2 + H
# Raw enthalpy is -3.7598047459315835 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -4.32.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HDO2 --> HO2 + D
# Raw enthalpy is -3.890749923613417 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -5.01.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction OD --> O + D
# Raw enthalpy is -4.470461939554964 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -5.59.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction OD --> O1D + D
# Raw enthalpy is -6.462677814679507 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -7.58.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction OH --> O + H
# Raw enthalpy is -4.39904483560279 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -4.96.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction OH --> O1D + H
# Raw enthalpy is -6.391260710727333 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -6.95.
# Positive excess energy: false, so reaction is endothermic
#
# Exothermic: 0, Endothermic: 16
#
# Reaction H2 --> Hpl + H
# Raw enthalpy is -18.077130521421452 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -18.64.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HD --> Dpl + H
# Raw enthalpy is -18.201514447027563 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -18.76.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HD --> Hpl + D
# Raw enthalpy is -18.133103287944206 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -19.25.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H2O --> OHpl + H
# Raw enthalpy is -18.114445699103285 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -18.67.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction H2O --> Opl + H2
# Raw enthalpy is -18.6534427100631 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -19.77.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HDO --> OHpl + D
# Raw enthalpy is -18.23986615742278 eV
# Mass to escape 2, so need a minimum of 1.1186701162466113 eV
# excess energy -19.36.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HDO --> ODpl + H
# Raw enthalpy is -18.314289206243767 eV
# Mass to escape 1, so need a minimum of 0.5593350581233056 eV
# excess energy -18.87.
# Positive excess energy: false, so reaction is endothermic
#
# Reaction HDO --> Opl + HD
# Raw enthalpy is -18.722890401859846 eV
# Mass to escape 3, so need a minimum of 1.678005174369917 eV
# excess energy -20.4.
# Positive excess energy: false, so reaction is endothermic
#
# Exothermic: 0, Endothermic: 8
